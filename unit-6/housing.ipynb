# %%
import pandas as pd

# %%
import csv as csv

# %%
housing_data = pd.read_csv('USA_Housing.csv')

# %%
housing_data.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
housing_data.shape
# Out:
# (5000, 7)

# %%
housing_data.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
# - Income and Ages for population > 50K
housing_data[housing_data['Area Population'] > 50000][['Avg. Area Income', 'Avg. Area House Age', 'Area Population']]
# Out:
#       Avg. Area Income  Avg. Area House Age  Area Population
# 6         64698.463428             6.025336     60828.249085
# 53        73078.204086             5.923906     54915.961782
# 64        59539.948450             6.018590     58600.827150
# 77        64826.371895             4.010907     60286.043101
# 83        80659.525444             5.436306     52947.036360
# 95        73698.696357             6.372731     51815.096419
# 117       73923.466274             7.005506     58745.312028
# 128       44806.005164             4.494571     57390.890074
# 144       47681.361733             6.890508     50908.978909
# 181       65316.996021             7.414875     55799.497481
# 208       51273.508853             7.032317     53811.894906
# 222       61978.848046             7.912276     56957.187750
# 228       66574.709994             5.550265     69575.449464
# 231       58088.438130             6.017831     51925.411613
# ...

# %%
housing_data[housing_data['Area Population'] > 50000][['Avg. Area Income', 'Avg. Area House Age', 'Area Population']].rename(columns = {'Avg. Area Income': 'Avg_Income'})
#housing_data.rename(columns = {'y':'year'})
# Out:
#         Avg_Income  Avg. Area House Age  Area Population
# 6     64698.463428             6.025336     60828.249085
# 53    73078.204086             5.923906     54915.961782
# 64    59539.948450             6.018590     58600.827150
# 77    64826.371895             4.010907     60286.043101
# 83    80659.525444             5.436306     52947.036360
# 95    73698.696357             6.372731     51815.096419
# 117   73923.466274             7.005506     58745.312028
# 128   44806.005164             4.494571     57390.890074
# 144   47681.361733             6.890508     50908.978909
# 181   65316.996021             7.414875     55799.497481
# 208   51273.508853             7.032317     53811.894906
# 222   61978.848046             7.912276     56957.187750
# 228   66574.709994             5.550265     69575.449464
# 231   58088.438130             6.017831     51925.411613
# 239   60081.176620             6.768524     60195.746267
# ...
